# %%
from langchain_experimental.agents.agent_toolkits.pandas.base import create_pandas_dataframe_agent
from langchain_openai import ChatOpenAI
import matplotlib.pyplot as plt
import pandas as pd
from dotenv import load_dotenv

#Load environment variables
load_dotenv()
# Out:
# True

# %%
import sys
sys.path.append("C:/Users/dao minh hai/Desktop/Dagpt/da")
from src.model.llms import load_llm
MODEL_NAME = "gpt-3.5-turbo"
llm = load_llm(model_name = MODEL_NAME)
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x0000011B3A519BE0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000011B3A51A660>, root_client=<openai.OpenAI object at 0x0000011B3A3234D0>, root_async_client=<openai.AsyncOpenAI object at 0x0000011B3A51A3C0>, temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'), max_tokens=1000)

# %%
llm.invoke("Hello. Who are you?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 llm.invoke("Hello. Who are you?")
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:383, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     371 @override
#     372 def invoke(
#     373     self,
#    (...)    378     **kwargs: Any,
#     379 ) -> BaseMessage:
#     380     config = ensure_config(config)
#     381     return cast(
#     382         "ChatGeneration",
# --> 383         self.generate_prompt(
#     384             [self._convert_input(input)],
#     385             stop=stop,
#     386             callbacks=config.get("callbacks"),
#     387             tags=config.get("tags"),
#     388             metadata=config.get("metadata"),
#     389             run_name=config.get("run_name"),
#     390             run_id=config.pop("run_id", None),
#     391             **kwargs,
#     392         ).generations[0][0],
#     393     ).message
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1006, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     997 @override
#     998 def generate_prompt(
#     999     self,
#    (...)   1003     **kwargs: Any,
#    1004 ) -> LLMResult:
#    1005     prompt_messages = [p.to_messages() for p in prompts]
# -> 1006     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:825, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     822 for i, m in enumerate(input_messages):
#     823     try:
#     824         results.append(
# --> 825             self._generate_with_cache(
#     826                 m,
#     827                 stop=stop,
#     828                 run_manager=run_managers[i] if run_managers else None,
#     829                 **kwargs,
#     830             )
#     831         )
#     832     except BaseException as e:
#     833         if run_managers:
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1072, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1070     result = generate_from_stream(iter(chunks))
#    1071 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1072     result = self._generate(
#    1073         messages, stop=stop, run_manager=run_manager, **kwargs
#    1074     )
#    1075 else:
#    1076     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1131, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1129     generation_info = {"headers": dict(raw_response.headers)}
#    1130 else:
# -> 1131     response = self.client.create(**payload)
#    1132 return self._create_chat_result(response, generation_info)
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1135, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1090 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1091 def create(
#    1092     self,
#    (...)   1132     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1133 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1134     validate_response_format(response_format)
# -> 1135     return self._post(
#    1136         "/chat/completions",
#    1137         body=maybe_transform(
#    1138             {
#    1139                 "messages": messages,
#    1140                 "model": model,
#    1141                 "audio": audio,
#    1142                 "frequency_penalty": frequency_penalty,
#    1143                 "function_call": function_call,
#    1144                 "functions": functions,
#    1145                 "logit_bias": logit_bias,
#    1146                 "logprobs": logprobs,
#    1147                 "max_completion_tokens": max_completion_tokens,
#    1148                 "max_tokens": max_tokens,
#    1149                 "metadata": metadata,
#    1150                 "modalities": modalities,
#    1151                 "n": n,
#    1152                 "parallel_tool_calls": parallel_tool_calls,
#    1153                 "prediction": prediction,
#    1154                 "presence_penalty": presence_penalty,
#    1155                 "prompt_cache_key": prompt_cache_key,
#    1156                 "reasoning_effort": reasoning_effort,
#    1157                 "response_format": response_format,
#    1158                 "safety_identifier": safety_identifier,
#    1159                 "seed": seed,
#    1160                 "service_tier": service_tier,
#    1161                 "stop": stop,
#    1162                 "store": store,
#    1163                 "stream": stream,
#    1164                 "stream_options": stream_options,
#    1165                 "temperature": temperature,
#    1166                 "tool_choice": tool_choice,
#    1167                 "tools": tools,
#    1168                 "top_logprobs": top_logprobs,
#    1169                 "top_p": top_p,
#    1170                 "user": user,
#    1171                 "web_search_options": web_search_options,
#    1172             },
#    1173             completion_create_params.CompletionCreateParamsStreaming
#    1174             if stream
#    1175             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1176         ),
#    1177         options=make_request_options(
#    1178             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1179         ),
#    1180         cast_to=ChatCompletion,
#    1181         stream=stream or False,
#    1182         stream_cls=Stream[ChatCompletionChunk],
#    1183     )
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df = pd.read_csv("../data/raw/sample_data.csv")


da_agent = create_pandas_dataframe_agent(
        llm = llm,
        df = df,
        agent_type = "tool-calling",
        allow_dangerous_code = True,
        verbose = True,
        return_intermediate_steps = True, 
    )
da_agent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tabulate'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 4
#       1 df = pd.read_csv("../data/raw/sample_data.csv")
# ----> 4 da_agent = create_pandas_dataframe_agent(
#       5         llm = llm,
#       6         df = df,
#       7         agent_type = "tool-calling",
#       8         allow_dangerous_code = True,
#       9         verbose = True,
#      10         return_intermediate_steps = True,
#      11     )
#      12 da_agent
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:313, in create_pandas_dataframe_agent(llm, df, agent_type, callback_manager, prefix, suffix, input_variables, verbose, return_intermediate_steps, max_iterations, max_execution_time, early_stopping_method, agent_executor_kwargs, include_df_in_prompt, number_of_head_rows, extra_tools, engine, allow_dangerous_code, **kwargs)
#     307     agent: Union[BaseSingleActionAgent, BaseMultiActionAgent] = RunnableAgent(
#     308         runnable=create_react_agent(llm, tools, prompt),  # type: ignore
#     309         input_keys_arg=["input"],
#     310         return_keys_arg=["output"],
#     311     )
#     312 elif agent_type in (AgentType.OPENAI_FUNCTIONS, "openai-tools", "tool-calling"):
# --> 313     prompt = _get_functions_prompt(
#     314         df,
#     315         prefix=prefix,
#     316         suffix=suffix,
#     317         include_df_in_prompt=include_df_in_prompt,
#     318         number_of_head_rows=number_of_head_rows,
#     319     )
#     320     if agent_type == AgentType.OPENAI_FUNCTIONS:
#     321         runnable = create_openai_functions_agent(
#     322             cast(BaseLanguageModel, llm), tools, prompt
#     323         )
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:148, in _get_functions_prompt(df, **kwargs)
#     144 def _get_functions_prompt(df: Any, **kwargs: Any) -> ChatPromptTemplate:
#     145     return (
#     146         _get_functions_multi_prompt(df, **kwargs)
#     147         if isinstance(df, list)
# --> 148         else _get_functions_single_prompt(df, **kwargs)
#     149     )
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:119, in _get_functions_single_prompt(df, prefix, suffix, include_df_in_prompt, number_of_head_rows)
#     110 def _get_functions_single_prompt(
#     111     df: Any,
#     112     *,
#    (...)    116     number_of_head_rows: int = 5,
#     117 ) -> ChatPromptTemplate:
#     118     if include_df_in_prompt:
# --> 119         df_head = str(df.head(number_of_head_rows).to_markdown())
#     120         suffix = (suffix or FUNCTIONS_WITH_DF).format(df_head=df_head)
#     121     prefix = prefix if prefix is not None else PREFIX_FUNCTIONS
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\pandas\core\frame.py:2988, in DataFrame.to_markdown(self, buf, mode, index, storage_options, **kwargs)
#    2986 kwargs.setdefault("tablefmt", "pipe")
#    2987 kwargs.setdefault("showindex", index)
# -> 2988 tabulate = import_optional_dependency("tabulate")
#    2989 result = tabulate.tabulate(self, **kwargs)
#    2990 if buf is None:
#
# File c:\Users\dao minh hai\Desktop\Dagpt\.venv\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'tabulate'.  Use pip or conda to install tabulate.
